# %% [markdown]
# ### Pandas: Work with lines! [Homework]
# > ** You must import all the necessary packages yourself. **
#
# > ** Write the code only where it is shown for recording. Do not delete comments! **

# %% [markdown]
# ### Step 1
#
# Please write the function `` `Load_Data (Filename)` ``, which will download data from the CSV file to the list of lists. Please write the function `` Load_Data (Filename) `` `, which will download data from the CSV file to` `Dataframe``` '. The file is `` num_house_Prices.csv`` 'provided with this Jupyter Notebook.
#
#
# **Note:**
#
# * If the file name is defined incorrectly, the function is `` Load_Data`` 'The following error message should display:
#
# ```{имя файла} does not exist```
# * ```str_house_prices.csv``` - это csv-файл, который является результатом вашей предыдущей домашней работы.

# %%
os.listdir()
# Out:
# ['dirty_str_house_prices.csv',
#  'HW_1_nlp.ipynb',
#  '.git',
#  'clean_house_prices.csv',
#  'Social_Network_Ads.csv']

# %%
os.path.exists(filename)
# Out:
# False

# %%
#Начало вашего кода
import pandas as pd
import os.path
import csv 
#load_data() function that downloads data from the csv file to the list of lists 
def load_data(filename):
        pd_data = [] 
        if not os.path.exists(filename):
                print('./SocialNetworkAds.csv does not exist')
                return None
        else:
                with open(filename, 'r') as file: 
                        reader = csv.reader(file) 
                        for row in reader: 
                                pd_data.append(row) 
                print(type(pd_data))
                return pd_data
#Конец вашего кода

# %%
filename = "./SocialNetworkAds.csv"
data1 = load_data(filename)
# Out:
# ./SocialNetworkAds.csv does not exist

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# ./SocialNetworkAds.csv does not exist
# ```

# %%
print(data1)
# Out:
# None

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# None
# ```

# %%
import pandas as pd

def load_data_1(filename):
    # Load and drop saved index column
    df = pd.read_csv(filename, index_col=0)   
    return df 
     
filename = "./clean_house_prices.csv"
data = load_data_1(filename)

# %%
data
# Out:
# [['Id',
#   'MSSubClass',
#   'MSZoning',
#   'LotArea',
#   'Street',
#   'LotShape',
#   'LandContour',
#   'Utilities',
#   'LotConfig',
#   'LandSlope',
#   'Neighborhood',
#   'Condition1',
#   'Condition2',
#   'BldgType',
#   'HouseStyle',
#   'OverallQual',
#   'OverallCond',
#   'YearBuilt',
#   'YearRemodAdd',
#   'RoofStyle',
#   'RoofMatl',
#   'Exterior1st',
#   'Exterior2nd',
#   'MasVnrType',
#   'MasVnrArea',
#   'ExterQual',
#   'ExterCond',
#   'Foundation',
#   'BsmtQual',
#   'BsmtCond',
#   'BsmtExposure',
#   'BsmtFinType1',
#   'BsmtFinSF1',
#   'BsmtFinType2',
#   'BsmtFinSF2',
#   'BsmtUnfSF',
#   'TotalBsmtSF',
#   'Heating',
#   'HeatingQC',
#   'CentralAir',
#   'Electrical',
#   '1stFlrSF',
#   '2ndFlrSF',
#   'LowQualFinSF',
#   'GrLivArea',
#   'BsmtFullBath',
#   'BsmtHalfBath',
#   'FullBath',
#   'HalfBath',
#   'BedroomAbvGr',
#   'KitchenAbvGr',
#   'KitchenQual',
#   'TotRmsAbvGrd',
#   'Functional',
#   'Fireplaces',
#   'GarageType',
#   'GarageYrBlt',
#   'GarageFinish',
#   'GarageCars',
#   'GarageArea',
#   'GarageQual',
#   'GarageCond',
#   'PavedDrive',
#   'WoodDeckSF',
#   'OpenPorchSF',
#   'EnclosedPorch',
#   '3SsnPorch',
#   'ScreenPorch',
#   'PoolArea',
#   'MiscVal',
#   'MoSold',
#   'YrSold',
#   'SaleType',
#   'SaleCondition',
#   'SalePrice'],
#  ['1',
#   '60',
#   'RL',
#   '8450',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '2003',
#   '2003',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '196.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '706',
#   'Unf',
#   '0',
#   '150',
#   '856',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '856',
#   '854',
#   '0',
#   '1710',
#   '1',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '8',
#   'Typ',
#   '0',
#   'Attchd',
#   '2003.0',
#   'RFn',
#   '2',
#   '548',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '61',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2008',
#   'WD',
#   'Normal',
#   '208500'],
#  ['2',
#   '20',
#   'RL',
#   '9600',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'FR2',
#   'Gtl',
#   'Veenker',
#   'Feedr',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '8',
#   '1976',
#   '1976',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Gd',
#   'ALQ',
#   '978',
#   'Unf',
#   '0',
#   '284',
#   '1262',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1262',
#   '0',
#   '0',
#   '1262',
#   '0',
#   '1',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1976.0',
#   'RFn',
#   '2',
#   '460',
#   'TA',
#   'TA',
#   'Y',
#   '298',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2007',
#   'WD',
#   'Normal',
#   '181500'],
#  ['3',
#   '60',
#   'RL',
#   '11250',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '2001',
#   '2002',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '162.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Mn',
#   'GLQ',
#   '486',
#   'Unf',
#   '0',
#   '434',
#   '920',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '920',
#   '866',
#   '0',
#   '1786',
#   '1',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '2001.0',
#   'RFn',
#   '2',
#   '608',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '42',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '9',
#   '2008',
#   'WD',
#   'Normal',
#   '223500'],
#  ['4',
#   '70',
#   'RL',
#   '9550',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Crawfor',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '1915',
#   '1970',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Shng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'Gd',
#   'No',
#   'ALQ',
#   '216',
#   'Unf',
#   '0',
#   '540',
#   '756',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '961',
#   '756',
#   '0',
#   '1717',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '1',
#   'Detchd',
#   '1998.0',
#   'Unf',
#   '3',
#   '642',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '35',
#   '272',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2006',
#   'WD',
#   'Abnorml',
#   '140000'],
#  ['5',
#   '60',
#   'RL',
#   '14260',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'FR2',
#   'Gtl',
#   'NoRidge',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '8',
#   '5',
#   '2000',
#   '2000',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '350.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'GLQ',
#   '655',
#   'Unf',
#   '0',
#   '490',
#   '1145',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1145',
#   '1053',
#   '0',
#   '2198',
#   '1',
#   '0',
#   '2',
#   '1',
#   '4',
#   '1',
#   'Gd',
#   '9',
#   'Typ',
#   '1',
#   'Attchd',
#   '2000.0',
#   'RFn',
#   '3',
#   '836',
#   'TA',
#   'TA',
#   'Y',
#   '192',
#   '84',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '12',
#   '2008',
#   'WD',
#   'Normal',
#   '250000'],
#  ['6',
#   '50',
#   'RL',
#   '14115',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Mitchel',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '5',
#   '5',
#   '1993',
#   '1995',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'Wood',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '732',
#   'Unf',
#   '0',
#   '64',
#   '796',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '796',
#   '566',
#   '0',
#   '1362',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '1993.0',
#   'Unf',
#   '2',
#   '480',
#   'TA',
#   'TA',
#   'Y',
#   '40',
#   '30',
#   '0',
#   '320',
#   '0',
#   '0',
#   '700',
#   '10',
#   '2009',
#   'WD',
#   'Normal',
#   '143000'],
#  ['7',
#   '20',
#   'RL',
#   '10084',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Somerst',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '8',
#   '5',
#   '2004',
#   '2005',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '186.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'Av',
#   'GLQ',
#   '1369',
#   'Unf',
#   '0',
#   '317',
#   '1686',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1694',
#   '0',
#   '0',
#   '1694',
#   '1',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '2004.0',
#   'RFn',
#   '2',
#   '636',
#   'TA',
#   'TA',
#   'Y',
#   '255',
#   '57',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '8',
#   '2007',
#   'WD',
#   'Normal',
#   '307000'],
#  ['8',
#   '60',
#   'RL',
#   '10382',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'NWAmes',
#   'PosN',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '6',
#   '1973',
#   '1973',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'Stone',
#   '240.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Mn',
#   'ALQ',
#   '859',
#   'BLQ',
#   '32',
#   '216',
#   '1107',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1107',
#   '983',
#   '0',
#   '2090',
#   '1',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '7',
#   'Typ',
#   '2',
#   'Attchd',
#   '1973.0',
#   'RFn',
#   '2',
#   '484',
#   'TA',
#   'TA',
#   'Y',
#   '235',
#   '204',
#   '228',
#   '0',
#   '0',
#   '0',
#   '350',
#   '11',
#   '2009',
#   'WD',
#   'Normal',
#   '200000'],
#  ['9',
#   '50',
#   'RM',
#   '6120',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'OldTown',
#   'Artery',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '7',
#   '5',
#   '1931',
#   '1950',
#   'Gable',
#   'CompShg',
#   'BrkFace',
#   'Wd Shng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '952',
#   '952',
#   'GasA',
#   'Gd',
#   'Y',
#   'FuseF',
#   '1022',
#   '752',
#   '0',
#   '1774',
#   '0',
#   '0',
#   '2',
#   '0',
#   '2',
#   '2',
#   'TA',
#   '8',
#   'Min1',
#   '2',
#   'Detchd',
#   '1931.0',
#   'Unf',
#   '2',
#   '468',
#   'Fa',
#   'TA',
#   'Y',
#   '90',
#   '0',
#   '205',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2008',
#   'WD',
#   'Abnorml',
#   '129900'],
#  ['10',
#   '190',
#   'RL',
#   '7420',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'BrkSide',
#   'Artery',
#   'Artery',
#   '2fmCon',
#   '1.5Unf',
#   '5',
#   '6',
#   '1939',
#   '1950',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'TA',
#   'No',
#   'GLQ',
#   '851',
#   'Unf',
#   '0',
#   '140',
#   '991',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1077',
#   '0',
#   '0',
#   '1077',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '2',
#   'TA',
#   '5',
#   'Typ',
#   '2',
#   'Attchd',
#   '1939.0',
#   'RFn',
#   '1',
#   '205',
#   'Gd',
#   'TA',
#   'Y',
#   '0',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '2008',
#   'WD',
#   'Normal',
#   '118000'],
#  ['11',
#   '20',
#   'RL',
#   '11200',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Sawyer',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1965',
#   '1965',
#   'Hip',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Rec',
#   '906',
#   'Unf',
#   '0',
#   '134',
#   '1040',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1040',
#   '0',
#   '0',
#   '1040',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'Detchd',
#   '1965.0',
#   'Unf',
#   '1',
#   '384',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2008',
#   'WD',
#   'Normal',
#   '129500'],
#  ['12',
#   '60',
#   'RL',
#   '11924',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '9',
#   '5',
#   '2005',
#   '2006',
#   'Hip',
#   'CompShg',
#   'WdShing',
#   'Wd Shng',
#   'Stone',
#   '286.0',
#   'Ex',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'No',
#   'GLQ',
#   '998',
#   'Unf',
#   '0',
#   '177',
#   '1175',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1182',
#   '1142',
#   '0',
#   '2324',
#   '1',
#   '0',
#   '3',
#   '0',
#   '4',
#   '1',
#   'Ex',
#   '11',
#   'Typ',
#   '2',
#   'BuiltIn',
#   '2005.0',
#   'Fin',
#   '3',
#   '736',
#   'TA',
#   'TA',
#   'Y',
#   '147',
#   '21',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2006',
#   'New',
#   'Partial',
#   '345000'],
#  ['13',
#   '20',
#   'RL',
#   '12968',
#   'Pave',
#   'IR2',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Sawyer',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1962',
#   '1962',
#   'Hip',
#   'CompShg',
#   'HdBoard',
#   'Plywood',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '737',
#   'Unf',
#   '0',
#   '175',
#   '912',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '912',
#   '0',
#   '0',
#   '912',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '4',
#   'Typ',
#   '0',
#   'Detchd',
#   '1962.0',
#   'Unf',
#   '1',
#   '352',
#   'TA',
#   'TA',
#   'Y',
#   '140',
#   '0',
#   '0',
#   '0',
#   '176',
#   '0',
#   '0',
#   '9',
#   '2008',
#   'WD',
#   'Normal',
#   '144000'],
#  ['14',
#   '20',
#   'RL',
#   '10652',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '7',
#   '5',
#   '2006',
#   '2007',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '306.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1494',
#   '1494',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1494',
#   '0',
#   '0',
#   '1494',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '2006.0',
#   'RFn',
#   '3',
#   '840',
#   'TA',
#   'TA',
#   'Y',
#   '160',
#   '33',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '8',
#   '2007',
#   'New',
#   'Partial',
#   '279500'],
#  ['15',
#   '20',
#   'RL',
#   '10920',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '5',
#   '1960',
#   '1960',
#   'Hip',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'BrkFace',
#   '212.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '733',
#   'Unf',
#   '0',
#   '520',
#   '1253',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1253',
#   '0',
#   '0',
#   '1253',
#   '1',
#   '0',
#   '1',
#   '1',
#   '2',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '1',
#   'Attchd',
#   '1960.0',
#   'RFn',
#   '1',
#   '352',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '213',
#   '176',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2008',
#   'WD',
#   'Normal',
#   '157000'],
#  ['16',
#   '45',
#   'RM',
#   '6120',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'BrkSide',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Unf',
#   '7',
#   '8',
#   '1929',
#   '2001',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '832',
#   '832',
#   'GasA',
#   'Ex',
#   'Y',
#   'FuseA',
#   '854',
#   '0',
#   '0',
#   '854',
#   '0',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'Detchd',
#   '1991.0',
#   'Unf',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '48',
#   '112',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2007',
#   'WD',
#   'Normal',
#   '132000'],
#  ['17',
#   '20',
#   'RL',
#   '11241',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '7',
#   '1970',
#   '1970',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'BrkFace',
#   '180.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '578',
#   'Unf',
#   '0',
#   '426',
#   '1004',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1004',
#   '0',
#   '0',
#   '1004',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '1',
#   'Attchd',
#   '1970.0',
#   'Fin',
#   '2',
#   '480',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '700',
#   '3',
#   '2010',
#   'WD',
#   'Normal',
#   '149000'],
#  ['19',
#   '20',
#   'RL',
#   '13695',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'SawyerW',
#   'RRAe',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '2004',
#   '2004',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'TA',
#   'TA',
#   'No',
#   'GLQ',
#   '646',
#   'Unf',
#   '0',
#   '468',
#   '1114',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1114',
#   '0',
#   '0',
#   '1114',
#   '1',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '0',
#   'Detchd',
#   '2004.0',
#   'Unf',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '102',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2008',
#   'WD',
#   'Normal',
#   '159000'],
#  ['20',
#   '20',
#   'RL',
#   '7560',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1958',
#   '1965',
#   'Hip',
#   'CompShg',
#   'BrkFace',
#   'Plywood',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'LwQ',
#   '504',
#   'Unf',
#   '0',
#   '525',
#   '1029',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1339',
#   '0',
#   '0',
#   '1339',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Min1',
#   '0',
#   'Attchd',
#   '1958.0',
#   'Unf',
#   '1',
#   '294',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2009',
#   'COD',
#   'Abnorml',
#   '139000'],
#  ['21',
#   '60',
#   'RL',
#   '14215',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '8',
#   '5',
#   '2005',
#   '2006',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '380.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'Av',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1158',
#   '1158',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1158',
#   '1218',
#   '0',
#   '2376',
#   '0',
#   '0',
#   '3',
#   '1',
#   '4',
#   '1',
#   'Gd',
#   '9',
#   'Typ',
#   '1',
#   'BuiltIn',
#   '2005.0',
#   'RFn',
#   '3',
#   '853',
#   'TA',
#   'TA',
#   'Y',
#   '240',
#   '154',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '11',
#   '2006',
#   'New',
#   'Partial',
#   '325300'],
#  ['22',
#   '45',
#   'RM',
#   '7449',
#   'Pave',
#   'Reg',
#   'Bnk',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'IDOTRR',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Unf',
#   '7',
#   '7',
#   '1930',
#   '1950',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '637',
#   '637',
#   'GasA',
#   'Ex',
#   'Y',
#   'FuseF',
#   '1108',
#   '0',
#   '0',
#   '1108',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1930.0',
#   'Unf',
#   '1',
#   '280',
#   'TA',
#   'TA',
#   'N',
#   '0',
#   '0',
#   '205',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2007',
#   'WD',
#   'Normal',
#   '139400'],
#  ['23',
#   '20',
#   'RL',
#   '9742',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '8',
#   '5',
#   '2002',
#   '2002',
#   'Hip',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '281.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1777',
#   '1777',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1795',
#   '0',
#   '0',
#   '1795',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '2002.0',
#   'RFn',
#   '2',
#   '534',
#   'TA',
#   'TA',
#   'Y',
#   '171',
#   '159',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '9',
#   '2008',
#   'WD',
#   'Normal',
#   '230000'],
#  ['24',
#   '120',
#   'RM',
#   '4224',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'MeadowV',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '1Story',
#   '5',
#   '7',
#   '1976',
#   '1976',
#   'Gable',
#   'CompShg',
#   'CemntBd',
#   'CmentBd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '840',
#   'Unf',
#   '0',
#   '200',
#   '1040',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1060',
#   '0',
#   '0',
#   '1060',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1976.0',
#   'Unf',
#   '2',
#   '572',
#   'TA',
#   'TA',
#   'Y',
#   '100',
#   '110',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2007',
#   'WD',
#   'Normal',
#   '129900'],
#  ['25',
#   '20',
#   'RL',
#   '8246',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Sawyer',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '8',
#   '1968',
#   '2001',
#   'Gable',
#   'CompShg',
#   'Plywood',
#   'Plywood',
#   'None',
#   '0.0',
#   'TA',
#   'Gd',
#   'CBlock',
#   'TA',
#   'TA',
#   'Mn',
#   'Rec',
#   '188',
#   'ALQ',
#   '668',
#   '204',
#   '1060',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1060',
#   '0',
#   '0',
#   '1060',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1968.0',
#   'Unf',
#   '1',
#   '270',
#   'TA',
#   'TA',
#   'Y',
#   '406',
#   '90',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2010',
#   'WD',
#   'Normal',
#   '154000'],
#  ['26',
#   '20',
#   'RL',
#   '14230',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '8',
#   '5',
#   '2007',
#   '2007',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '640.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1566',
#   '1566',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1600',
#   '0',
#   '0',
#   '1600',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '2007.0',
#   'RFn',
#   '3',
#   '890',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '56',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2009',
#   'WD',
#   'Normal',
#   '256300'],
#  ['27',
#   '20',
#   'RL',
#   '7200',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '7',
#   '1951',
#   '2000',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'Mn',
#   'BLQ',
#   '234',
#   'Rec',
#   '486',
#   '180',
#   '900',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '900',
#   '0',
#   '0',
#   '900',
#   '0',
#   '1',
#   '1',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Detchd',
#   '2005.0',
#   'Unf',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '222',
#   '32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2010',
#   'WD',
#   'Normal',
#   '134800'],
#  ['28',
#   '20',
#   'RL',
#   '11478',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '8',
#   '5',
#   '2007',
#   '2008',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '200.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'No',
#   'GLQ',
#   '1218',
#   'Unf',
#   '0',
#   '486',
#   '1704',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1704',
#   '0',
#   '0',
#   '1704',
#   '1',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '2008.0',
#   'RFn',
#   '3',
#   '772',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '50',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2010',
#   'WD',
#   'Normal',
#   '306000'],
#  ['29',
#   '20',
#   'RL',
#   '16321',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1957',
#   '1997',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'Gd',
#   'BLQ',
#   '1277',
#   'Unf',
#   '0',
#   '207',
#   '1484',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1600',
#   '0',
#   '0',
#   '1600',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '2',
#   'Attchd',
#   '1957.0',
#   'RFn',
#   '1',
#   '319',
#   'TA',
#   'TA',
#   'Y',
#   '288',
#   '258',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '12',
#   '2006',
#   'WD',
#   'Normal',
#   '207500'],
#  ['30',
#   '30',
#   'RM',
#   '6324',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'BrkSide',
#   'Feedr',
#   'RRNn',
#   '1Fam',
#   '1Story',
#   '4',
#   '6',
#   '1927',
#   '1950',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '520',
#   '520',
#   'GasA',
#   'Fa',
#   'N',
#   'SBrkr',
#   '520',
#   '0',
#   '0',
#   '520',
#   '0',
#   '0',
#   '1',
#   '0',
#   '1',
#   '1',
#   'Fa',
#   '4',
#   'Typ',
#   '0',
#   'Detchd',
#   '1920.0',
#   'Unf',
#   '1',
#   '240',
#   'Fa',
#   'TA',
#   'Y',
#   '49',
#   '0',
#   '87',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2008',
#   'WD',
#   'Normal',
#   '68500'],
#  ['31',
#   '70',
#   'C (all)',
#   '8500',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'IDOTRR',
#   'Feedr',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '4',
#   '4',
#   '1920',
#   '1950',
#   'Gambrel',
#   'CompShg',
#   'BrkFace',
#   'BrkFace',
#   'None',
#   '0.0',
#   'TA',
#   'Fa',
#   'BrkTil',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '649',
#   '649',
#   'GasA',
#   'TA',
#   'N',
#   'SBrkr',
#   '649',
#   '668',
#   '0',
#   '1317',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Detchd',
#   '1920.0',
#   'Unf',
#   '1',
#   '250',
#   'TA',
#   'Fa',
#   'N',
#   '0',
#   '54',
#   '172',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2008',
#   'WD',
#   'Normal',
#   '40000'],
#  ['32',
#   '20',
#   'RL',
#   '8544',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'Sawyer',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1966',
#   '2006',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1228',
#   '1228',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1228',
#   '0',
#   '0',
#   '1228',
#   '0',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1966.0',
#   'Unf',
#   '1',
#   '271',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '65',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2008',
#   'WD',
#   'Normal',
#   '149350'],
#  ['33',
#   '20',
#   'RL',
#   '11049',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '8',
#   '5',
#   '2007',
#   '2007',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'Av',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1234',
#   '1234',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1234',
#   '0',
#   '0',
#   '1234',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '0',
#   'Attchd',
#   '2007.0',
#   'RFn',
#   '2',
#   '484',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '30',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '2008',
#   'WD',
#   'Normal',
#   '179900'],
#  ['34',
#   '20',
#   'RL',
#   '10552',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1959',
#   '1959',
#   'Hip',
#   'CompShg',
#   'BrkFace',
#   'BrkFace',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Rec',
#   '1018',
#   'Unf',
#   '0',
#   '380',
#   '1398',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1700',
#   '0',
#   '0',
#   '1700',
#   '0',
#   '1',
#   '1',
#   '1',
#   '4',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1959.0',
#   'RFn',
#   '2',
#   '447',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '38',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2010',
#   'WD',
#   'Normal',
#   '165500'],
#  ['35',
#   '120',
#   'RL',
#   '7313',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '1Story',
#   '9',
#   '5',
#   '2005',
#   '2005',
#   'Hip',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'BrkFace',
#   '246.0',
#   'Ex',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'No',
#   'GLQ',
#   '1153',
#   'Unf',
#   '0',
#   '408',
#   '1561',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1561',
#   '0',
#   '0',
#   '1561',
#   '1',
#   '0',
#   '2',
#   '0',
#   '2',
#   '1',
#   'Ex',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '2005.0',
#   'Fin',
#   '2',
#   '556',
#   'TA',
#   'TA',
#   'Y',
#   '203',
#   '47',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '8',
#   '2007',
#   'WD',
#   'Normal',
#   '277500'],
#  ['36',
#   '60',
#   'RL',
#   '13418',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '8',
#   '5',
#   '2004',
#   '2005',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '132.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'Av',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1117',
#   '1117',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1132',
#   '1320',
#   '0',
#   '2452',
#   '0',
#   '0',
#   '3',
#   '1',
#   '4',
#   '1',
#   'Gd',
#   '9',
#   'Typ',
#   '1',
#   'BuiltIn',
#   '2004.0',
#   'Fin',
#   '3',
#   '691',
#   'TA',
#   'TA',
#   'Y',
#   '113',
#   '32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '9',
#   '2006',
#   'WD',
#   'Normal',
#   '309000'],
#  ['37',
#   '20',
#   'RL',
#   '10859',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1994',
#   '1995',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1097',
#   '1097',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1097',
#   '0',
#   '0',
#   '1097',
#   '0',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1995.0',
#   'Unf',
#   '2',
#   '672',
#   'TA',
#   'TA',
#   'Y',
#   '392',
#   '64',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2009',
#   'WD',
#   'Normal',
#   '145000'],
#  ['38',
#   '20',
#   'RL',
#   '8532',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1954',
#   '1990',
#   'Hip',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'BrkFace',
#   '650.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Rec',
#   '1213',
#   'Unf',
#   '0',
#   '84',
#   '1297',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1297',
#   '0',
#   '0',
#   '1297',
#   '0',
#   '1',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '1',
#   'Attchd',
#   '1954.0',
#   'Fin',
#   '2',
#   '498',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '10',
#   '2009',
#   'WD',
#   'Normal',
#   '153000'],
#  ['39',
#   '20',
#   'RL',
#   '7922',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '7',
#   '1953',
#   '2007',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'Gd',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'GLQ',
#   '731',
#   'Unf',
#   '0',
#   '326',
#   '1057',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1057',
#   '0',
#   '0',
#   '1057',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Detchd',
#   '1953.0',
#   'Unf',
#   '1',
#   '246',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '52',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '2010',
#   'WD',
#   'Abnorml',
#   '109000'],
#  ['41',
#   '20',
#   'RL',
#   '8658',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '5',
#   '1965',
#   '1965',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'BrkFace',
#   '101.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Rec',
#   '643',
#   'Unf',
#   '0',
#   '445',
#   '1088',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1324',
#   '0',
#   '0',
#   '1324',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1965.0',
#   'RFn',
#   '2',
#   '440',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '138',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '12',
#   '2006',
#   'WD',
#   'Abnorml',
#   '160000'],
#  ['42',
#   '20',
#   'RL',
#   '16905',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Timber',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1959',
#   '1959',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'Gd',
#   'CBlock',
#   'TA',
#   'TA',
#   'Gd',
#   'BLQ',
#   '967',
#   'Unf',
#   '0',
#   '383',
#   '1350',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1328',
#   '0',
#   '0',
#   '1328',
#   '0',
#   '1',
#   '1',
#   '1',
#   '2',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '2',
#   'Attchd',
#   '1959.0',
#   'RFn',
#   '1',
#   '308',
#   'TA',
#   'TA',
#   'P',
#   '0',
#   '104',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2007',
#   'WD',
#   'Normal',
#   '170000'],
#  ['43',
#   '85',
#   'RL',
#   '9180',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'SawyerW',
#   'Norm',
#   'Norm',
#   '1Fam',
#   'SFoyer',
#   '5',
#   '7',
#   '1983',
#   '1983',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Av',
#   'ALQ',
#   '747',
#   'LwQ',
#   '93',
#   '0',
#   '840',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '884',
#   '0',
#   '0',
#   '884',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '1983.0',
#   'RFn',
#   '2',
#   '504',
#   'TA',
#   'Gd',
#   'Y',
#   '240',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '12',
#   '2007',
#   'WD',
#   'Normal',
#   '144000'],
#  ['44',
#   '20',
#   'RL',
#   '9200',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1975',
#   '1980',
#   'Hip',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Av',
#   'LwQ',
#   '280',
#   'BLQ',
#   '491',
#   '167',
#   '938',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '938',
#   '0',
#   '0',
#   '938',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'Detchd',
#   '1977.0',
#   'Unf',
#   '1',
#   '308',
#   'TA',
#   'TA',
#   'Y',
#   '145',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2008',
#   'WD',
#   'Normal',
#   '130250'],
#  ['45',
#   '20',
#   'RL',
#   '7945',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '6',
#   '1959',
#   '1959',
#   'Gable',
#   'CompShg',
#   'BrkFace',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '179',
#   'BLQ',
#   '506',
#   '465',
#   '1150',
#   'GasA',
#   'Ex',
#   'Y',
#   'FuseA',
#   '1150',
#   '0',
#   '0',
#   '1150',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1959.0',
#   'RFn',
#   '1',
#   '300',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2006',
#   'WD',
#   'Normal',
#   '141000'],
#  ['46',
#   '120',
#   'RL',
#   '7658',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '1Story',
#   '9',
#   '5',
#   '2005',
#   '2005',
#   'Hip',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'BrkFace',
#   '412.0',
#   'Ex',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'No',
#   'GLQ',
#   '456',
#   'Unf',
#   '0',
#   '1296',
#   '1752',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1752',
#   '0',
#   '0',
#   '1752',
#   '1',
#   '0',
#   '2',
#   '0',
#   '2',
#   '1',
#   'Ex',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '2005.0',
#   'RFn',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '196',
#   '82',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2010',
#   'WD',
#   'Normal',
#   '319900'],
#  ['47',
#   '50',
#   'RL',
#   '12822',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'Mitchel',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '7',
#   '5',
#   '2003',
#   '2003',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'No',
#   'GLQ',
#   '1351',
#   'Unf',
#   '0',
#   '83',
#   '1434',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1518',
#   '631',
#   '0',
#   '2149',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '2003.0',
#   'RFn',
#   '2',
#   '670',
#   'TA',
#   'TA',
#   'Y',
#   '168',
#   '43',
#   '0',
#   '0',
#   '198',
#   '0',
#   '0',
#   '8',
#   '2009',
#   'WD',
#   'Abnorml',
#   '239686'],
#  ['48',
#   '20',
#   'FV',
#   '11096',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Somerst',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '8',
#   '5',
#   '2006',
#   '2006',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'GLQ',
#   '24',
#   'Unf',
#   '0',
#   '1632',
#   '1656',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1656',
#   '0',
#   '0',
#   '1656',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '0',
#   'Attchd',
#   '2006.0',
#   'RFn',
#   '3',
#   '826',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '146',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2007',
#   'WD',
#   'Normal',
#   '249700'],
#  ['50',
#   '20',
#   'RL',
#   '7742',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Sawyer',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '7',
#   '1966',
#   '1966',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '763',
#   'Unf',
#   '0',
#   '192',
#   '955',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '955',
#   '0',
#   '0',
#   '955',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1966.0',
#   'Unf',
#   '1',
#   '386',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '2007',
#   'WD',
#   'Normal',
#   '127000'],
#  ['51',
#   '60',
#   'RL',
#   '13869',
#   'Pave',
#   'IR2',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Gilbert',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '6',
#   '6',
#   '1997',
#   '1997',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'GLQ',
#   '182',
#   'Unf',
#   '0',
#   '612',
#   '794',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '794',
#   '676',
#   '0',
#   '1470',
#   '0',
#   '1',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1997.0',
#   'Fin',
#   '2',
#   '388',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '75',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2007',
#   'WD',
#   'Normal',
#   '177000'],
#  ['52',
#   '50',
#   'RM',
#   '6240',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'BrkSide',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '6',
#   '6',
#   '1934',
#   '1950',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '816',
#   '816',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '816',
#   '0',
#   '360',
#   '1176',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '1',
#   'Detchd',
#   '1985.0',
#   'Unf',
#   '2',
#   '528',
#   'TA',
#   'TA',
#   'Y',
#   '112',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '400',
#   '9',
#   '2006',
#   'WD',
#   'Normal',
#   '114500'],
#  ['53',
#   '90',
#   'RM',
#   '8472',
#   'Grvl',
#   'IR2',
#   'Bnk',
#   'AllPub',
#   'Corner',
#   'Mod',
#   'IDOTRR',
#   'RRNn',
#   'Norm',
#   'Duplex',
#   '1Story',
#   '5',
#   '5',
#   '1963',
#   '1963',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'Fa',
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Gd',
#   'LwQ',
#   '104',
#   'GLQ',
#   '712',
#   '0',
#   '816',
#   'GasA',
#   'TA',
#   'N',
#   'SBrkr',
#   '816',
#   '0',
#   '0',
#   '816',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'CarPort',
#   '1963.0',
#   'Unf',
#   '2',
#   '516',
#   'TA',
#   'TA',
#   'Y',
#   '106',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2010',
#   'WD',
#   'Normal',
#   '110000'],
#  ['54',
#   '20',
#   'RL',
#   '50271',
#   'Pave',
#   'IR1',
#   'Low',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Veenker',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '9',
#   '5',
#   '1981',
#   '1987',
#   'Gable',
#   'WdShngl',
#   'WdShing',
#   'Wd Shng',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'CBlock',
#   'Ex',
#   'TA',
#   'Gd',
#   'GLQ',
#   '1810',
#   'Unf',
#   '0',
#   '32',
#   '1842',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1842',
#   '0',
#   '0',
#   '1842',
#   '2',
#   '0',
#   '0',
#   '1',
#   '0',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '1',
#   'Attchd',
#   '1981.0',
#   'Fin',
#   '3',
#   '894',
#   'TA',
#   'TA',
#   'Y',
#   '857',
#   '72',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '11',
#   '2006',
#   'WD',
#   'Normal',
#   '385000'],
#  ['55',
#   '80',
#   'RL',
#   '7134',
#   'Pave',
#   'Reg',
#   'Bnk',
#   'AllPub',
#   'Inside',
#   'Mod',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   'SLvl',
#   '5',
#   '5',
#   '1955',
#   '1955',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '384',
#   'Unf',
#   '0',
#   '0',
#   '384',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1360',
#   '0',
#   '0',
#   '1360',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Min1',
#   '1',
#   'Detchd',
#   '1962.0',
#   'Unf',
#   '2',
#   '572',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '50',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2007',
#   'WD',
#   'Normal',
#   '130000'],
#  ['56',
#   '20',
#   'RL',
#   '10175',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '5',
#   '1964',
#   '1964',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'Plywood',
#   'BrkFace',
#   '272.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '490',
#   'Unf',
#   '0',
#   '935',
#   '1425',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1425',
#   '0',
#   '0',
#   '1425',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '1964.0',
#   'RFn',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '407',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2008',
#   'WD',
#   'Normal',
#   '180500'],
#  ['57',
#   '160',
#   'FV',
#   '2645',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Somerst',
#   'Norm',
#   'Norm',
#   'Twnhs',
#   '2Story',
#   '8',
#   '5',
#   '1999',
#   '2000',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'BrkFace',
#   '456.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '649',
#   'Unf',
#   '0',
#   '321',
#   '970',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '983',
#   '756',
#   '0',
#   '1739',
#   '1',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '0',
#   'Attchd',
#   '1999.0',
#   'Fin',
#   '2',
#   '480',
#   'TA',
#   'TA',
#   'Y',
#   '115',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '8',
#   '2009',
#   'WD',
#   'Abnorml',
#   '172500'],
#  ['58',
#   '60',
#   'RL',
#   '11645',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '2004',
#   '2004',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '860',
#   '860',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '860',
#   '860',
#   '0',
#   '1720',
#   '0',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '0',
#   'Attchd',
#   '2004.0',
#   'RFn',
#   '2',
#   '565',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '70',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '8',
#   '2006',
#   'WD',
#   'Normal',
#   '196500'],
#  ['59',
#   '60',
#   'RL',
#   '13682',
#   'Pave',
#   'IR2',
#   'HLS',
#   'AllPub',
#   'CulDSac',
#   'Gtl',
#   'StoneBr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '10',
#   '5',
#   '2006',
#   '2006',
#   'Hip',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '1031.0',
#   'Ex',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'Gd',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1410',
#   '1410',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1426',
#   '1519',
#   '0',
#   '2945',
#   '0',
#   '0',
#   '3',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '10',
#   'Typ',
#   '1',
#   'BuiltIn',
#   '2006.0',
#   'Fin',
#   '3',
#   '641',
#   'TA',
#   'TA',
#   'Y',
#   '192',
#   '0',
#   '37',
#   '0',
#   '0',
#   '0',
#   '0',
#   '10',
#   '2006',
#   'New',
#   'Partial',
#   '438780'],
#  ['60',
#   '20',
#   'RL',
#   '7200',
#   'Pave',
#   'Reg',
#   'Bnk',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '7',
#   '1972',
#   '1972',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'Av',
#   'ALQ',
#   '632',
#   'Unf',
#   '0',
#   '148',
#   '780',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '780',
#   '0',
#   '0',
#   '780',
#   '0',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '4',
#   'Typ',
#   '0',
#   'Detchd',
#   '1973.0',
#   'Unf',
#   '1',
#   '352',
#   'TA',
#   'TA',
#   'Y',
#   '196',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '2008',
#   'WD',
#   'Normal',
#   '124900'],
#  ['61',
#   '20',
#   'RL',
#   '13072',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'SawyerW',
#   'RRAe',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '5',
#   '2004',
#   '2004',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'ALQ',
#   '941',
#   'Unf',
#   '0',
#   '217',
#   '1158',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1158',
#   '0',
#   '0',
#   '1158',
#   '1',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Detchd',
#   '2006.0',
#   'Unf',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '50',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2006',
#   'New',
#   'Partial',
#   '158000'],
#  ['62',
#   '75',
#   'RM',
#   '7200',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'IDOTRR',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2.5Unf',
#   '5',
#   '7',
#   '1920',
#   '1996',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'Fa',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '530',
#   '530',
#   'GasA',
#   'TA',
#   'N',
#   'SBrkr',
#   '581',
#   '530',
#   '0',
#   '1111',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'Fa',
#   '6',
#   'Typ',
#   '0',
#   'Detchd',
#   '1935.0',
#   'Unf',
#   '1',
#   '288',
#   'TA',
#   'TA',
#   'N',
#   '0',
#   '0',
#   '144',
#   '0',
#   '0',
#   '0',
#   '0',
#   '3',
#   '2007',
#   'WD',
#   'Normal',
#   '101000'],
#  ['63',
#   '120',
#   'RL',
#   '6442',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '1Story',
#   '8',
#   '5',
#   '2006',
#   '2006',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '178.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'Gd',
#   'Mn',
#   'GLQ',
#   '24',
#   'Unf',
#   '0',
#   '1346',
#   '1370',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1370',
#   '0',
#   '0',
#   '1370',
#   '0',
#   '0',
#   '2',
#   '0',
#   '2',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '2006.0',
#   'RFn',
#   '2',
#   '484',
#   'TA',
#   'TA',
#   'Y',
#   '120',
#   '49',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '10',
#   '2007',
#   'WD',
#   'Normal',
#   '202500'],
#  ['64',
#   '70',
#   'RM',
#   '10300',
#   'Pave',
#   'IR1',
#   'Bnk',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'OldTown',
#   'RRAn',
#   'Feedr',
#   '1Fam',
#   '2Story',
#   '7',
#   '6',
#   '1921',
#   '1950',
#   'Gable',
#   'CompShg',
#   'Stucco',
#   'Stucco',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'BrkTil',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '576',
#   '576',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '902',
#   '808',
#   '0',
#   '1710',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '9',
#   'Typ',
#   '0',
#   'Detchd',
#   '1990.0',
#   'Unf',
#   '2',
#   '480',
#   'TA',
#   'TA',
#   'Y',
#   '12',
#   '11',
#   '64',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2010',
#   'WD',
#   'Normal',
#   '140000'],
#  ['65',
#   '60',
#   'RL',
#   '9375',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '1997',
#   '1998',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '573.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '739',
#   'Unf',
#   '0',
#   '318',
#   '1057',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1057',
#   '977',
#   '0',
#   '2034',
#   '1',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '8',
#   'Typ',
#   '0',
#   'Attchd',
#   '1998.0',
#   'RFn',
#   '2',
#   '645',
#   'TA',
#   'TA',
#   'Y',
#   '576',
#   '36',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2009',
#   'WD',
#   'Normal',
#   '219500'],
#  ['66',
#   '60',
#   'RL',
#   '9591',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NridgHt',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '8',
#   '5',
#   '2004',
#   '2005',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '344.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Ex',
#   'TA',
#   'Av',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1143',
#   '1143',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1143',
#   '1330',
#   '0',
#   '2473',
#   '0',
#   '0',
#   '2',
#   '1',
#   '4',
#   '1',
#   'Gd',
#   '9',
#   'Typ',
#   '1',
#   'BuiltIn',
#   '2004.0',
#   'RFn',
#   '3',
#   '852',
#   'TA',
#   'TA',
#   'Y',
#   '192',
#   '151',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '10',
#   '2007',
#   'WD',
#   'Normal',
#   '317000'],
#  ['67',
#   '20',
#   'RL',
#   '19900',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'PosA',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '7',
#   '5',
#   '1970',
#   '1989',
#   'Gable',
#   'CompShg',
#   'Plywood',
#   'Plywood',
#   'BrkFace',
#   '287.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Gd',
#   'GLQ',
#   '912',
#   'Unf',
#   '0',
#   '1035',
#   '1947',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '2207',
#   '0',
#   '0',
#   '2207',
#   '1',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '7',
#   'Min1',
#   '1',
#   'Attchd',
#   '1970.0',
#   'RFn',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '301',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2010',
#   'WD',
#   'Normal',
#   '180000'],
#  ['68',
#   '20',
#   'RL',
#   '10665',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '7',
#   '5',
#   '2003',
#   '2003',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '167.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'GLQ',
#   '1013',
#   'Unf',
#   '0',
#   '440',
#   '1453',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1479',
#   '0',
#   '0',
#   '1479',
#   '1',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Typ',
#   '0',
#   'Attchd',
#   '2003.0',
#   'RFn',
#   '2',
#   '558',
#   'TA',
#   'TA',
#   'Y',
#   '144',
#   '29',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2007',
#   'WD',
#   'Normal',
#   '226000'],
#  ['69',
#   '30',
#   'RM',
#   '4608',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'OldTown',
#   'Artery',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '4',
#   '6',
#   '1945',
#   '1950',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'Gd',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '747',
#   '747',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '747',
#   '0',
#   '0',
#   '747',
#   '0',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '4',
#   'Typ',
#   '0',
#   'Attchd',
#   '1945.0',
#   'Unf',
#   '1',
#   '220',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2010',
#   'WD',
#   'Normal',
#   '80000'],
#  ['70',
#   '50',
#   'RL',
#   '15593',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'ClearCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '7',
#   '4',
#   '1953',
#   '1953',
#   'Gable',
#   'CompShg',
#   'BrkFace',
#   'AsbShng',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '603',
#   'Unf',
#   '0',
#   '701',
#   '1304',
#   'GasW',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1304',
#   '983',
#   '0',
#   '2287',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '7',
#   'Typ',
#   '1',
#   'Attchd',
#   '1953.0',
#   'Fin',
#   '2',
#   '667',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '21',
#   '114',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2006',
#   'WD',
#   'Normal',
#   '225000'],
#  ['71',
#   '20',
#   'RL',
#   '13651',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '7',
#   '6',
#   '1973',
#   '1973',
#   'Gable',
#   'CompShg',
#   'Plywood',
#   'Plywood',
#   'BrkFace',
#   '1115.0',
#   'TA',
#   'Gd',
#   'CBlock',
#   'Gd',
#   'TA',
#   'Gd',
#   'ALQ',
#   '1880',
#   'Unf',
#   '0',
#   '343',
#   '2223',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '2223',
#   '0',
#   '0',
#   '2223',
#   '1',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '8',
#   'Typ',
#   '2',
#   'Attchd',
#   '1973.0',
#   'Fin',
#   '2',
#   '516',
#   'TA',
#   'TA',
#   'Y',
#   '300',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '2007',
#   'WD',
#   'Normal',
#   '244000'],
#  ['72',
#   '20',
#   'RL',
#   '7599',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Mitchel',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '4',
#   '6',
#   '1982',
#   '2006',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'Plywood',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '565',
#   'Unf',
#   '0',
#   '280',
#   '845',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '845',
#   '0',
#   '0',
#   '845',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'TA',
#   '4',
#   'Typ',
#   '0',
#   'Detchd',
#   '1987.0',
#   'Unf',
#   '2',
#   '360',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2007',
#   'WD',
#   'Normal',
#   '129500'],
#  ['73',
#   '60',
#   'RL',
#   '10141',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Gilbert',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '1998',
#   '1998',
# ...
#   'TA',
#   'CBlock',
#   'Gd',
#   'TA',
#   'No',
#   'ALQ',
#   '837',
#   'Unf',
#   '0',
#   '105',
#   '942',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1291',
#   '1230',
#   '0',
#   '2521',
#   '1',
#   '0',
#   '2',
#   '1',
#   '5',
#   '1',
#   'TA',
#   '10',
#   'Maj1',
#   '1',
#   'Attchd',
#   '1973.0',
#   'Fin',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '728',
#   '20',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2006',
#   'WD',
#   'Normal',
#   '151400'],
#  ['1070',
#   '45',
#   'RL',
#   '9600',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Unf',
#   '5',
#   '7',
#   '1949',
#   '2003',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '220',
#   'Unf',
#   '0',
#   '625',
#   '845',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '893',
#   '0',
#   '0',
#   '893',
#   '0',
#   '1',
#   '1',
#   '0',
#   '2',
#   '1',
#   'Gd',
#   '4',
#   'Typ',
#   '0',
#   'Detchd',
#   '1985.0',
#   'Unf',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2007',
#   'WD',
#   'Normal',
#   '135000'],
#  ['1071',
#   '20',
#   'RL',
#   '10152',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1956',
#   '1956',
#   'Hip',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'BrkFace',
#   '120.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '586',
#   'Unf',
#   '0',
#   '462',
#   '1048',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1048',
#   '0',
#   '0',
#   '1048',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1956.0',
#   'Unf',
#   '1',
#   '286',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '20',
#   '0',
#   '0',
#   '192',
#   '0',
#   '0',
#   '6',
#   '2007',
#   'WD',
#   'Normal',
#   '135000'],
#  ['1072',
#   '60',
#   'RL',
#   '11700',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NWAmes',
#   'RRAn',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '6',
#   '6',
#   '1968',
#   '1968',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'Rec',
#   '298',
#   'Unf',
#   '0',
#   '429',
#   '727',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '829',
#   '727',
#   '0',
#   '1556',
#   '0',
#   '0',
#   '1',
#   '1',
#   '4',
#   '1',
#   'TA',
#   '8',
#   'Typ',
#   '0',
#   'Attchd',
#   '1968.0',
#   'Unf',
#   '2',
#   '441',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2009',
#   'WD',
#   'Normal',
#   '154000'],
#  ['1073',
#   '50',
#   'RL',
#   '7585',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Edwards',
#   'Artery',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '5',
#   '3',
#   '1948',
#   '1950',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Fa',
#   'Fa',
#   'Mn',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '810',
#   '810',
#   'GasA',
#   'Fa',
#   'Y',
#   'FuseA',
#   '1002',
#   '454',
#   '0',
#   '1456',
#   '1',
#   '1',
#   '1',
#   '0',
#   '4',
#   '1',
#   'TA',
#   '7',
#   'Typ',
#   '1',
#   'Detchd',
#   '1954.0',
#   'Unf',
#   '1',
#   '280',
#   'TA',
#   'TA',
#   'P',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '8',
#   '2006',
#   'WD',
#   'Normal',
#   '91500'],
#  ['1074',
#   '60',
#   'RL',
#   '7950',
#   'Pave',
#   'IR1',
#   'Bnk',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Edwards',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '6',
#   '6',
#   '1977',
#   '1977',
#   'Hip',
#   'CompShg',
#   'HdBoard',
#   'Plywood',
#   'BrkFace',
#   '140.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '535',
#   'Unf',
#   '0',
#   '155',
#   '690',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '698',
#   '728',
#   '0',
#   '1426',
#   '0',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1977.0',
#   'Fin',
#   '2',
#   '440',
#   'TA',
#   'TA',
#   'Y',
#   '252',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2009',
#   'WD',
#   'Normal',
#   '159500'],
#  ['1075',
#   '20',
#   'RL',
#   '8556',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '7',
#   '5',
#   '2006',
#   '2006',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1240',
#   '1240',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1240',
#   '0',
#   '0',
#   '1240',
#   '0',
#   '0',
#   '2',
#   '0',
#   '2',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '2006.0',
#   'RFn',
#   '3',
#   '826',
#   'TA',
#   'TA',
#   'Y',
#   '140',
#   '93',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2007',
#   'WD',
#   'Normal',
#   '194000'],
#  ['1076',
#   '70',
#   'RL',
#   '13125',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Crawfor',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '6',
#   '1940',
#   '1984',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '410',
#   'Unf',
#   '0',
#   '390',
#   '800',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '960',
#   '780',
#   '0',
#   '1740',
#   '0',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '2',
#   'Attchd',
#   '1940.0',
#   'Unf',
#   '1',
#   '240',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2007',
#   'CWD',
#   'Normal',
#   '219500'],
#  ['1077',
#   '50',
#   'RL',
#   '10800',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'OldTown',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '5',
#   '8',
#   '1936',
#   '1989',
#   'Gable',
#   'CompShg',
#   'Wd Sdng',
#   'Wd Sdng',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'Fa',
#   'TA',
#   'No',
#   'ALQ',
#   '626',
#   'Unf',
#   '0',
#   '170',
#   '796',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '1096',
#   '370',
#   '0',
#   '1466',
#   '0',
#   '1',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Min1',
#   '1',
#   'Attchd',
#   '1950.0',
#   'Unf',
#   '2',
#   '566',
#   'TA',
#   'TA',
#   'Y',
#   '436',
#   '21',
#   '0',
#   '0',
#   '0',
#   '0',
#   '500',
#   '4',
#   '2006',
#   'WD',
#   'Normal',
#   '170000'],
#  ['1078',
#   '20',
#   'RL',
#   '15870',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1969',
#   '1969',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'Plywood',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'Mn',
#   'BLQ',
#   '75',
#   'Rec',
#   '791',
#   '230',
#   '1096',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1096',
#   '0',
#   '0',
#   '1096',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1969.0',
#   'Fin',
#   '1',
#   '299',
#   'TA',
#   'TA',
#   'Y',
#   '240',
#   '32',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '3',
#   '2006',
#   'WD',
#   'Abnorml',
#   '138800'],
#  ['1079',
#   '120',
#   'RM',
#   '4435',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '1Story',
#   '6',
#   '5',
#   '2004',
#   '2004',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '169.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Mn',
#   'GLQ',
#   '662',
#   'Unf',
#   '0',
#   '186',
#   '848',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '848',
#   '0',
#   '0',
#   '848',
#   '1',
#   '0',
#   '1',
#   '0',
#   '1',
#   '1',
#   'Gd',
#   '3',
#   'Typ',
#   '1',
#   'Attchd',
#   '2004.0',
#   'RFn',
#   '2',
#   '420',
#   'TA',
#   'TA',
#   'Y',
#   '140',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2006',
#   'WD',
#   'Normal',
#   '155900'],
#  ['1080',
#   '20',
#   'RL',
#   '8775',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1994',
#   '1994',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '495',
#   'Unf',
#   '0',
#   '495',
#   '990',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '990',
#   '0',
#   '0',
#   '990',
#   '0',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '1996.0',
#   'Unf',
#   '1',
#   '299',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '64',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2007',
#   'WD',
#   'Normal',
#   '126000'],
#  ['1081',
#   '20',
#   'RL',
#   '11040',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NWAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '7',
#   '1971',
#   '2004',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '144.0',
#   'Gd',
#   'Gd',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '656',
#   'Unf',
#   '0',
#   '602',
#   '1258',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1258',
#   '0',
#   '0',
#   '1258',
#   '0',
#   '1',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '1971.0',
#   'RFn',
#   '2',
#   '528',
#   'TA',
#   'TA',
#   'Y',
#   '55',
#   '0',
#   '0',
#   '216',
#   '0',
#   '0',
#   '0',
#   '10',
#   '2008',
#   'COD',
#   'Abnorml',
#   '145000'],
#  ['1082',
#   '20',
#   'RL',
#   '7500',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Sawyer',
#   'Feedr',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '5',
#   '5',
#   '1963',
#   '1963',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'ALQ',
#   '824',
#   'Unf',
#   '0',
#   '216',
#   '1040',
#   'GasA',
#   'Fa',
#   'Y',
#   'SBrkr',
#   '1040',
#   '0',
#   '0',
#   '1040',
#   '1',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '1963.0',
#   'Fin',
#   '1',
#   '308',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '0',
#   '220',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2010',
#   'WD',
#   'Normal',
#   '133000'],
#  ['1083',
#   '20',
#   'RL',
#   '8749',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '7',
#   '5',
#   '2002',
#   '2002',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '100.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1459',
#   '1459',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1459',
#   '0',
#   '0',
#   '1459',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '2002.0',
#   'RFn',
#   '2',
#   '527',
#   'TA',
#   'TA',
#   'Y',
#   '192',
#   '39',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '9',
#   '2007',
#   'WD',
#   'Normal',
#   '192000'],
#  ['1084',
#   '20',
#   'RL',
#   '8800',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'NAmes',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1Story',
#   '6',
#   '6',
#   '1964',
#   '1964',
#   'Hip',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'BrkFace',
#   '425.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '553',
#   'Unf',
#   '0',
#   '698',
#   '1251',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '1251',
#   '0',
#   '0',
#   '1251',
#   '1',
#   '0',
#   '1',
#   '0',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '2',
#   'Attchd',
#   '1964.0',
#   'RFn',
#   '1',
#   '461',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '116',
#   '0',
#   '0',
#   '0',
#   '0',
#   '700',
#   '3',
#   '2006',
#   'WD',
#   'Normal',
#   '160000'],
#  ['1085',
#   '60',
#   'RL',
#   '13031',
#   'Pave',
#   'IR2',
#   'Lvl',
#   'AllPub',
#   'Corner',
#   'Gtl',
#   'Gilbert',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '6',
#   '5',
#   '1995',
#   '1996',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'ALQ',
#   '592',
#   'Unf',
#   '0',
#   '99',
#   '691',
#   'GasA',
#   'Gd',
#   'Y',
#   'SBrkr',
#   '691',
#   '807',
#   '0',
#   '1498',
#   '0',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '1',
#   'Attchd',
#   '1995.0',
#   'Fin',
#   '2',
#   '409',
#   'TA',
#   'TA',
#   'Y',
#   '315',
#   '44',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '7',
#   '2006',
#   'WD',
#   'Normal',
#   '187500'],
#  ['1086',
#   '85',
#   'RL',
#   '9069',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'SawyerW',
#   'Norm',
#   'Norm',
#   '1Fam',
#   'SFoyer',
#   '6',
#   '6',
#   '1992',
#   '1992',
#   'Gable',
#   'CompShg',
#   'HdBoard',
#   'HdBoard',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Av',
#   'GLQ',
#   '747',
#   'Unf',
#   '0',
#   '189',
#   '936',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '996',
#   '0',
#   '0',
#   '996',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2',
#   '1',
#   'Gd',
#   '5',
#   'Typ',
#   '0',
#   'Attchd',
#   '1992.0',
#   'Unf',
#   '2',
#   '564',
#   'TA',
#   'TA',
#   'Y',
#   '120',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2010',
#   'WD',
#   'Normal',
#   '147000'],
#  ['1087',
#   '160',
#   'RM',
#   '1974',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'MeadowV',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '2Story',
#   '4',
#   '5',
#   '1973',
#   '1973',
#   'Gable',
#   'CompShg',
#   'CemntBd',
#   'CmentBd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'CBlock',
#   'TA',
#   'TA',
#   'No',
#   'BLQ',
#   '334',
#   'Unf',
#   '0',
#   '212',
#   '546',
#   'GasA',
#   'TA',
#   'Y',
#   'SBrkr',
#   '546',
#   '546',
#   '0',
#   '1092',
#   '0',
#   '0',
#   '1',
#   '1',
#   '3',
#   '1',
#   'TA',
#   '6',
#   'Typ',
#   '0',
#   'Attchd',
#   '1973.0',
#   'RFn',
#   '1',
#   '286',
#   'TA',
#   'TA',
#   'Y',
#   '120',
#   '96',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2010',
#   'WD',
#   'Normal',
#   '83500'],
#  ['1088',
#   '60',
#   'FV',
#   '10574',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Somerst',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '8',
#   '5',
#   '2005',
#   '2006',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'Mn',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '1082',
#   '1082',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1082',
#   '871',
#   '0',
#   '1953',
#   '0',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '9',
#   'Typ',
#   '1',
#   'Attchd',
#   '2005.0',
#   'RFn',
#   '3',
#   '1043',
#   'TA',
#   'TA',
#   'Y',
#   '160',
#   '50',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5',
#   '2009',
#   'WD',
#   'Normal',
#   '252000'],
#  ['1089',
#   '160',
#   'RM',
#   '2522',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Edwards',
#   'Norm',
#   'Norm',
#   'Twnhs',
#   '2Story',
#   '7',
#   '5',
#   '2004',
#   '2004',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'Stone',
#   '50.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'Unf',
#   '0',
#   'Unf',
#   '0',
#   '970',
#   '970',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '970',
#   '739',
#   '0',
#   '1709',
#   '0',
#   '0',
#   '2',
#   '0',
#   '3',
#   '1',
#   'Gd',
#   '7',
#   'Maj1',
#   '0',
#   'Detchd',
#   '2004.0',
#   'Unf',
#   '2',
#   '380',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '40',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2006',
#   'WD',
#   'Normal',
#   '137500'],
#  ['1090',
#   '120',
#   'FV',
#   '3316',
#   'Pave',
#   'IR1',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Somerst',
#   'Norm',
#   'Norm',
#   'TwnhsE',
#   '1Story',
#   '8',
#   '5',
#   '2005',
#   '2005',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '1039',
#   'Unf',
#   '0',
#   '208',
#   '1247',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '1247',
#   '0',
#   '0',
#   '1247',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   'Gd',
#   '4',
#   'Typ',
#   '1',
#   'Attchd',
#   '2005.0',
#   'Fin',
#   '2',
#   '550',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '84',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '4',
#   '2006',
#   'WD',
#   'Normal',
#   '197000'],
#  ['1092',
#   '160',
#   'FV',
#   '2160',
#   'Pave',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'Somerst',
#   'Norm',
#   'Norm',
#   'Twnhs',
#   '2Story',
#   '7',
#   '5',
#   '1999',
#   '2000',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'BrkFace',
#   '212.0',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'BLQ',
#   '510',
#   'Unf',
#   '0',
#   '90',
#   '600',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '624',
#   '628',
#   '0',
#   '1252',
#   '1',
#   '0',
#   '2',
#   '1',
#   '2',
#   '1',
#   'Gd',
#   '4',
#   'Typ',
#   '0',
#   'Detchd',
#   '1999.0',
#   'Unf',
#   '2',
#   '462',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '48',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '3',
#   '2008',
#   'WD',
#   'Normal',
#   '160000'],
#  ['1093',
#   '50',
#   'RL',
#   '8400',
#   'Pave',
#   'Reg',
#   'Bnk',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'SWISU',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '1.5Fin',
#   '6',
#   '5',
#   '1925',
#   '1950',
#   'Gable',
#   'CompShg',
#   'MetalSd',
#   'MetalSd',
#   'None',
#   '0.0',
#   'TA',
#   'TA',
#   'PConc',
#   'TA',
#   'TA',
#   'No',
#   'Rec',
#   '423',
#   'Unf',
#   '0',
#   '758',
#   '1181',
#   'GasA',
#   'Fa',
#   'Y',
#   'SBrkr',
#   '1390',
#   '304',
#   '0',
#   '1694',
#   '0',
#   '0',
#   '2',
#   '0',
#   '4',
#   '1',
#   'TA',
#   '7',
#   'Typ',
#   '1',
#   'Detchd',
#   '1925.0',
#   'Unf',
#   '2',
#   '576',
#   'TA',
#   'TA',
#   'Y',
#   '342',
#   '0',
#   '128',
#   '0',
#   '0',
#   '0',
#   '0',
#   '6',
#   '2008',
#   'WD',
#   'Normal',
#   '136500'],
#  ...]

# %%
print(data.columns.values.tolist())
# Out:
# ['MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# ['Id', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']
# ```

# %%
""" 
the clean csv file provided has more values than the dirty csv  
so in step 1 we need to get the clean version to compare it to the cleaned dirty one in step 4 
so i didnt really understand why the expected result here is of the dirty data set values 
and not the clean ones 
"""

# %%
data
# Out:
#         Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0        1       RL   Pave      Reg         LVL    Allpub    Inside       GTL
# 1        2       RL   Pave      Reg         LVL    Allpub       FR2       GTL
# 2        3       RL   Pave      IR1         LVL    Allpub    Inside       GTL
# 3        4       RL   Pave      IR1         LVL    Allpub    Corner       GTL
# 4        5       RL   Pave      IR1         LVL    Allpub       FR2       GTL
# ...    ...      ...    ...      ...         ...       ...       ...       ...
# 1333  1456       RL   Pave      Reg         LVL    Allpub    Inside       GTL
# 1334  1457       RL   Pave      Reg         LVL    Allpub    Inside       GTL
# 1335  1458       RL   Pave      Reg         LVL    Allpub    Inside       GTL
# 1336  1459       RL   Pave      Reg         LVL    Allpub    Inside       GTL
# 1337  1460       RL   Pave      Reg         LVL    Allpub    Inside       GTL
#
#      Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 0         Collgcr       Norm  ...      Sbrkr          GD        TYP
# 1         Veenker      Feedr  ...      Sbrkr          TA        TYP
# 2         Collgcr       Norm  ...      Sbrkr          GD        TYP
# 3         Crawfor       Norm  ...      Sbrkr          GD        TYP
# 4         Noridge       Norm  ...      Sbrkr          GD        TYP
# ...           ...        ...  ...        ...         ...        ...
# 1333      Gilbert       Norm  ...      Sbrkr          TA        TYP
# 1334       Nwames       Norm  ...      Sbrkr          TA       Min1
# 1335      Crawfor       Norm  ...      Sbrkr          GD        TYP
# 1336        Names       Norm  ...      Fusea          GD        TYP
# 1337      Edwards       Norm  ...      Sbrkr          TA        TYP
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 0        Attchd          RFN         TA         TA          Y       WD
# 1        Attchd          RFN         TA         TA          Y       WD
# 2        Attchd          RFN         TA         TA          Y       WD
# 3        Detchd          UNF         TA         TA          Y       WD
# 4        Attchd          RFN         TA         TA          Y       WD
# ...         ...          ...        ...        ...        ...      ...
# 1333     Attchd          RFN         TA         TA          Y       WD
# 1334     Attchd          UNF         TA         TA          Y       WD
# 1335     Attchd          RFN         TA         TA          Y       WD
# 1336     Attchd          UNF         TA         TA          Y       WD
# 1337     Attchd          FIN         TA         TA          Y       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [1338 rows x 39 columns]

# %% [markdown]
# **Распечатайте первые и последние 5 строк pandas.DataFrame:**

# %%
#Начало вашего кода
print(data.head())
print(data.tail())
#Конец вашего кода
# Out:
#     MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1           60       RL     8450   Pave      Reg         Lvl    AllPub
# 2           20       RL     9600   Pave      Reg         Lvl    AllPub
# 3           60       RL    11250   Pave      IR1         Lvl    AllPub
# 4           70       RL     9550   Pave      IR1         Lvl    AllPub
# 5           60       RL    14260   Pave      IR1         Lvl    AllPub
#
#    LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# Id                                   ...
# 1     Inside       Gtl      CollgCr  ...             0         0           0
# 2        FR2       Gtl      Veenker  ...             0         0           0
# 3     Inside       Gtl      CollgCr  ...             0         0           0
# 4     Corner       Gtl      Crawfor  ...           272         0           0
# 5        FR2       Gtl      NoRidge  ...             0         0           0
#
#    PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition SalePrice
# Id
# 1         0        0       2    2008       WD        Normal  208500.0
# 2         0        0       5    2007       WD        Normal  181500.0
# 3         0        0       9    2008       WD        Normal  223500.0
# 4         0        0       2    2006       WD       Abnorml  140000.0
# 5         0        0      12    2008       WD        Normal  250000.0
#
# [5 rows x 74 columns]
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1456          60       RL     7917   Pave      Reg         Lvl    AllPub
# 1457          20       RL    13175   Pave      Reg         Lvl    AllPub
# 1458          70       RL     9042   Pave      Reg         Lvl    AllPub
# 1459          20       RL     9717   Pave      Reg         Lvl    AllPub
# 1460          20       RL     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch  \
# Id                                     ...
# 1456    Inside       Gtl      Gilbert  ...             0         0
# 1457    Inside       Gtl       NWAmes  ...             0         0
# 1458    Inside       Gtl      Crawfor  ...             0         0
# 1459    Inside       Gtl        NAmes  ...           112         0
# 1460    Inside       Gtl      Edwards  ...             0         0
#
#      ScreenPorch PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# Id
# 1456           0        0        0       8    2007       WD        Normal
# 1457           0        0        0       2    2010       WD        Normal
# 1458           0        0     2500       5    2010       WD        Normal
# 1459           0        0        0       4    2010       WD        Normal
# 1460           0        0        0       6    2008       WD        Normal
#
#      SalePrice
# Id
# 1456  175000.0
# 1457  210000.0
# 1458  266500.0
# 1459  142125.0
# 1460  147500.0
#
# [5 rows x 74 columns]

# %% [markdown]
# ###  Expected results:
#
# ```
# Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0   1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1   2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2   3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3   4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4   5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
# Neighborhood Condition1  ... Electrical KitchenQual Functional GarageType  \
# 0      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 1 Veenker Feed R ... SCRKR TA PAY CHECKED
# 2      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 3      Crawfor       Norm  ...      SBrkr          Gd        Typ     Detchd
# 4      NoRidge       Norm  ...      SBrkr          Gd        Typ     Attchd
#
# GarageFinish GarageQual GarageCond PavedDrive SaleType SaleCondition
# 0 RFn NOT WA
# 1 RFn Normal WD
# 2 RFn NOT WA
# 3 UNF TA TA Y WD ABNORML
# 44 RFn NOT WA
#
# [5 rows x 39 columns]
# Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 1333  1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1334  1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1335  1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1336  1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1337  1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
# Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 1333 Gilbert Norm ... Sbrkr take type
# 1334 NWAMES NORM ... SBRKR TA Min1
# 1335      Crawfor       Norm  ...      SBrkr          Gd        Typ
# 1336        NAmes       Norm  ...      FuseA          Gd        Typ
# 1337 Edwards norm ... SBRK TAKE TYPE
#
# GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 1333 Atchd RFn RFn THE WD
# 1334 Attchd Unf THE WD
# 1335 Attchd RFn RFn THE WD
# 1336 Atchd Unf THE WD
# 1337 Atchd Fin THE WD
#
# Salecondition
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [5 rows x 39 columns]
# ```

# %% [markdown]
# ### Step 2
#
# Run the code block below and try to get some insight into the data you are looking at.

# %%
pd_data=data.copy()
#pd_data.reset_index(inplace=True)

# %% [markdown]
# Please implement a ```count_by_group(data,column)``` function that returns statistics by group ```column``` for column ```column``` in a ```DataFrame```. The statistics contain the number of unique values ​​in the column.

# %%
#Начало вашего кода
def count_by_group(data,column):
    counts = {} 
    for value in data[column]: 
        if value in counts: 
            counts[value] += 1 
        else: 
            counts[value] = 1 
    data1 = pd.Series(counts, name=column)
    data1 = data1.sort_index()
    return data1
#Конец вашего кода

def count_by_group1(data,column):
    counts = {} 
    for value in data[column]: 
        if value in counts: 
            counts[value] += 1 
        else: 
            counts[value] = 1 
    data1 = pd.Series(counts, name=column)
    data1 = data1.sort_values(ascending=False)
    return data1

# %%
data.groupby('LotShape').count()
# Out:
#           MSSubClass  MSZoning  LotArea  Street  LandContour  Utilities  \
# LotShape
# IR1              459       459      459     459          459        459
# IR2               40        40       40      40           40         40
# IR3               10        10       10      10           10         10
# Lvl                1         1        1       0            1          1
# Reg              828       828      828     828          828        828
#
#           LotConfig  LandSlope  Neighborhood  Condition1  ...  EnclosedPorch  \
# LotShape                                                  ...
# IR1             459        459           459         459  ...            459
# IR2              40         40            40          40  ...             40
# IR3              10         10            10          10  ...             10
# Lvl               1          1             1           1  ...              1
# Reg             828        828           828         828  ...            828
#
#           3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# LotShape
# IR1             459          459       459      459     459     459       459
# IR2              40           40        40       40      40      40        40
# IR3              10           10        10       10      10      10        10
# Lvl               1            1         1        1       1       1         1
# Reg             828          828       828      828     828     828       828
#
#           SaleCondition  SalePrice
# LotShape
# IR1                 459        459
# IR2                  40         40
# IR3                  10         10
# Lvl                   1          0
# Reg                 828        828
#
# [5 rows x 73 columns]

# %%
result=count_by_group(data=pd_data,column="LotShape")
print("Lotter", "\n", result)
# Out:
# Lotter
#  IR1    459
# IR2     40
# IR3     10
# Lvl      1
# Reg    828
# Name: LotShape, dtype: int64

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# Lotter
# IR1 459
# IR2     40
# IR3     10
# Reg    829
# Name: LotShape, dtype: int64
# ```

# %%
results = {col: count_by_group1(pd_data, col)
           for col in pd_data.select_dtypes(include="object").columns} 
print(type(results)) # class "dict" 
print(results)
# Out:
# <class 'dict'>
# {'MSZoning': RL         1066
# RM          191
# FV           62
# RH           11
# C (all)       8
# Name: MSZoning, dtype: int64, 'Street': Pave    1332
# Grvl       5
# NaN        1
# Name: Street, dtype: int64, 'LotShape': Reg    828
# IR1    459
# IR2     40
# IR3     10
# Lvl      1
# Name: LotShape, dtype: int64, 'LandContour': Lvl       1205
# Bnk         52
# HLS         48
# Low         32
# AllPub       1
# Name: LandContour, dtype: int64, 'Utilities': AllPub    1336
# NoSeWa       1
# Inside       1
# Name: Utilities, dtype: int64, 'LotConfig': Inside     956
# Corner     244
# CulDSac     90
# FR2         43
# FR3          4
# Gtl          1
# Name: LotConfig, dtype: int64, 'LandSlope': Gtl        1264
# Mod          61
# Sev          12
# Edwards       1
# Name: LandSlope, dtype: int64, 'Neighborhood': NAmes      209
# CollgCr    146
# OldTown    100
# Somerst     83
# Gilbert     77
# NridgHt     75
# NWAmes      73
# Sawyer      69
# Edwards     69
# SawyerW     53
# Crawfor     50
# BrkSide     47
# Mitchel     42
# NoRidge     41
# Timber      37
# IDOTRR      29
# ClearCr     26
# StoneBr     25
# SWISU       20
# Blmngtn     17
# BrDale      15
# MeadowV     12
# Veenker     11
# NPkVill      9
# Blueste      2
# Norm         1
# Name: Neighborhood, dtype: int64, 'Condition1': Norm      1162
# Feedr       63
# Artery      43
# RRAn        26
# PosN        19
# RRAe        10
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64, 'Condition2': Norm      1323
# Feedr        5
# Artery       2
# RRNn         2
# PosN         2
# PosA         1
# RRAn         1
# RRAe         1
# 1Fam         1
# Name: Condition2, dtype: int64, 'BldgType': 1Fam      1137
# TwnhsE     112
# Twnhs       38
# Duplex      28
# 2fmCon      22
# 2Story       1
# Name: BldgType, dtype: int64, 'HouseStyle': 1Story    657
# 2Story    425
# 1.5Fin    134
# SLvl       64
# SFoyer     30
# 1.5Unf     11
# 2.5Unf     10
# 2.5Fin      6
# 4           1
# Name: HouseStyle, dtype: int64, 'YearRemodAdd': 1950     145
# 2006      90
# 2005      71
# 2007      71
# 2004      60
#         ...
# 1982       5
# 1983       5
# 1952       4
# 1951       4
# Gable      1
# Name: YearRemodAdd, Length: 62, dtype: int64, 'RoofStyle': Gable      1036
# Hip         272
# Flat         11
# Gambrel      10
# Mansard       6
# Shed          2
# CompShg       1
# Name: RoofStyle, dtype: int64, 'RoofMatl': CompShg    1313
# Tar&Grv       9
# WdShngl       6
# WdShake       5
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# MetalSd       1
# Name: RoofMatl, dtype: int64, 'Exterior1st': VinylSd    486
# HdBoard    212
# MetalSd    200
# Wd Sdng    183
# Plywood    100
# CemntBd     52
# BrkFace     44
# Stucco      21
# WdShing     20
# AsbShng     15
# Stone        2
# BrkComm      1
# ImStucc      1
# CBlock       1
# Name: Exterior1st, dtype: int64, 'Exterior2nd': VinylSd    475
# MetalSd    197
# HdBoard    196
# Wd Sdng    176
# Plywood    127
# CmentBd     51
# Wd Shng     32
# Stucco      23
# BrkFace     22
# AsbShng     16
# ImStucc     10
# Brk Cmn      6
# AsphShn      2
# Stone        2
# Other        1
# CBlock       1
# NaN          1
# Name: Exterior2nd, dtype: int64, 'MasVnrType': NaN        762
# BrkFace    432
# Stone      128
# BrkCmn      15
# 0.0          1
# Name: MasVnrType, dtype: int64, 'MasVnrArea': 0.0      759
# 180.0      8
# 72.0       8
# 108.0      8
# 16.0       7
#         ...
# 89.0       1
# 333.0      1
# 921.0      1
# 594.0      1
# 119.0      1
# Name: MasVnrArea, Length: 326, dtype: int64, 'ExterQual': TA    803
# Gd    477
# Ex     51
# Fa      7
# Name: ExterQual, dtype: int64, 'ExterCond': TA        1182
# Gd         137
# Fa          16
# Ex           2
# CBlock       1
# Name: ExterCond, dtype: int64, 'Foundation': PConc     620
# CBlock    579
# BrkTil    129
# Stone       6
# Wood        3
# Fa          1
# Name: Foundation, dtype: int64, 'BsmtQual': TA    595
# Gd    592
# Ex    120
# Fa     31
# Name: BsmtQual, dtype: int64, 'BsmtCond': TA    1236
# Gd      62
# Fa      38
# Po       1
# No       1
# Name: BsmtCond, dtype: int64, 'BsmtExposure': No     886
# Av     213
# Gd     127
# Mn     111
# Unf      1
# Name: BsmtExposure, dtype: int64, 'BsmtFinType1': GLQ    402
# Unf    391
# ALQ    209
# BLQ    141
# Rec    125
# LwQ     69
# 0        1
# Name: BsmtFinType1, dtype: int64, 'BsmtFinSF1': 0       391
# 24       12
# 16        9
# 686       5
# 936       5
#        ...
# 1324      1
# 429       1
# 1460      1
# 222       1
# 830       1
# Name: BsmtFinSF1, Length: 622, dtype: int64, 'BsmtFinType2': Unf    1175
# Rec      53
# LwQ      46
# BLQ      32
# ALQ      19
# GLQ      12
# 0         1
# Name: BsmtFinType2, dtype: int64, 'TotalBsmtSF': 864     31
# 672     15
# 912     14
# 1040    13
# 768     12
#         ..
# 654      1
# 1838     1
# 1581     1
# 611      1
# 1542     1
# Name: TotalBsmtSF, Length: 701, dtype: int64, 'Heating': GasA    1317
# GasW      16
# Grav       3
# OthW       1
# Gd         1
# Name: Heating, dtype: int64, 'HeatingQC': Ex    704
# TA    380
# Gd    216
# Fa     36
# Po      1
# N       1
# Name: HeatingQC, dtype: int64, 'CentralAir': Y        1277
# N          60
# SBrkr       1
# Name: CentralAir, dtype: int64, 'Electrical': SBrkr    1241
# FuseA      76
# FuseF      17
# FuseP       2
# Mix         1
# 796         1
# Name: Electrical, dtype: int64, 'KitchenAbvGr': 1     1298
# 2       38
# 3        1
# TA       1
# Name: KitchenAbvGr, dtype: int64, 'KitchenQual': TA    649
# Gd    568
# Ex     97
# Fa     23
# 6       1
# Name: KitchenQual, dtype: int64, 'TotRmsAbvGrd': 6       378
# 7       309
# 5       248
# 8       171
# 4        79
# 9        69
# 10       44
# 11       18
# 3        12
# 12        9
# Min2      1
# Name: TotRmsAbvGrd, dtype: int64, 'Functional': Typ     1254
# Min2      29
# Min1      28
# Mod       11
# Maj1      10
# Maj2       4
# Sev        1
# 0          1
# Name: Functional, dtype: int64, 'Fireplaces': 1         631
# 0         590
# 2         111
# 3           5
# Detchd      1
# Name: Fireplaces, dtype: int64, 'GarageType': Attchd     852
# Detchd     368
# BuiltIn     85
# Basment     19
# CarPort      7
# 2Types       6
# 1950.0       1
# Name: GarageType, dtype: int64, 'GarageYrBlt': 2005.0    65
# 2006.0    58
# 2004.0    53
# 2003.0    47
# 2007.0    45
#           ..
# 1933.0     1
# 1900.0     1
# 1906.0     1
# 1927.0     1
# Unf        1
# Name: GarageYrBlt, Length: 98, dtype: int64, 'GarageFinish': Unf    579
# RFn    413
# Fin    345
# 1        1
# Name: GarageFinish, dtype: int64, 'GarageArea': 440     48
# 576     47
# 240     37
# 484     33
# 528     31
#         ..
# 1390     1
# 842      1
# 816      1
# 230      1
# Fa       1
# Name: GarageArea, Length: 436, dtype: int64, 'GarageQual': TA    1271
# Fa      47
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64, 'GarageCond': TA    1286
# Fa      33
# Gd       9
# Po       7
# Ex       2
# Y        1
# Name: GarageCond, dtype: int64, 'PavedDrive': Y      1256
# N        54
# P        27
# 168       1
# Name: PavedDrive, dtype: int64, 'YrSold': 2009    308
# 2007    305
# 2006    291
# 2008    273
# 2010    160
# WD        1
# Name: YrSold, dtype: int64, 'SaleType': WD        1157
# New        117
# COD         42
# ConLD        6
# ConLI        4
# CWD          4
# ConLw        4
# Con          2
# Oth          1
# Normal       1
# Name: SaleType, dtype: int64, 'SaleCondition': Normal     1103
# Partial     120
# Abnorml      86
# Family       20
# Alloca        7
# AdjLand       1
# 112000        1
# Name: SaleCondition, dtype: int64}

# %% [markdown]
# ###  Expected results:
#
# ```
# <class 'dict'>
# {'MSZoning': RL         1066
# RM          191
# FV           62
# RH           11
# C (all)       8
# Name: MSZoning, dtype: int64, 'Street': Pave    1333
# Grvl       5
# Name: Street, dtype: int64, 'LotShape': Reg    829
# IR1 459
# IR2     40
# IR3     10
# Name: LotShape, dtype: int64, 'LandContour': Lvl    1206
# BNK 52
# HLS      48
# Low      32
# Name: LandContour, dtype: int64, 'Utilities': AllPub    1337
# Nome avoid 1
# Name: Utilities, dtype: int64, 'LotConfig': Inside     957
# Corner     244
# CulDSac     90
# 43 difference
# Fr3 4
# Name: LotConfig, dtype: int64, 'LandSlope': Gtl    1265
# Mod      61
# Sev      12
# Name: LandSlope, dtype: int64, 'Neighborhood': NAmes      209
# Collgcr 146
# Oldtown 100
# Somerst     83
# Gilbert     77
# NridgHt     75
# The baby 73
# Edwards     70
# Sawyer      69
# SawyerW     53
# Crawfor     50
# Brxide 47
# Mitchel     42
# NoRidge     41
# Timber      37
# Idotrr 29
# ClearCr     26
# StoneBr     25
# Swisu 20
# Blmngtn     17
# Brdale 15
# MeadowV     12
# Veenker 11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64, 'Condition1': Norm      1162
# Feedr       63
# Artery      43
# RRAN 26
# Poson 19
# Rrae 10
# Put 8
# Rrn 5
# RRNe         2
# Name: Condition1, dtype: int64, 'Condition2': Norm      1324
# Feedr        5
# Artery       2
# Poson 2
# Rrn 2
# Put 1
# IRRAN 1
# Rrae 1
# Name: Condition2, dtype: int64, 'BldgType': 1Fam      1138
# Tunhse 112
# Tunhs 38
# Duplex      28
# 2fmCon      22
# Name: BldgType, dtype: int64, 'HouseStyle': 1Story    657
# 2Story    426
# 1.5pen 134
# SLvl       64
# SFOYER 30
# 1.5Unf     11
# 2.5Unf     10
# 2.5Fin 6
# Name: HouseStyle, dtype: int64, 'RoofStyle': Gable      1037
# Hip         272
# Flat         11
# Gambrel      10
# Mansard 6
# Shed          2
# Name: RoofStyle, dtype: int64, 'RoofMatl': CompShg    1314
# Tar & GRR9
# Wdshngl 6
# WdShake       5
# Roll          1
# Membrane 1
# ClyTile       1
# Metal         1
# Name: RoofMatl, dtype: int64, 'Exterior1st': VinylSd    486
# HdBoard    211
# MetalSd    201
# WD SDNG 183
# Plywood    100
# Cemntbd 52
# BrkFace     44
# Stucco 21
# WdShing     20
# AsbShng     15
# Stone        2
# Shimasta 1
# BrkComm      1
# CBlock       1
# Name: Exterior1st, dtype: int64, 'Exterior2nd': VinylSd    475
# MetalSd    197
# HdBoard    197
# WD SDNG 176
# Plywood    127
# CmentBd     51
# Wd Shng     32
# Stucco 23
# BrkFace     22
# AsbShng     16
# Shimastak 10
# Brk Cmn      6
# AsphShn      2
# Stone        2
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64, 'MasVnrType': None       763
# BrkFace    432
# Stone      128
# Brkcmn 15
# Name: MasVnrType, dtype: int64, 'ExterQual': TA    803
# Gd    477
# Ex     51
# Fa      7
# Name: ExterQual, dtype: int64, 'ExterCond': TA    1183
# Gd     137
# Fa      16
# Ex       2
# Name: ExterCond, dtype: int64, 'Foundation': PConc     620
# CBlock    580
# On the Brk 129
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64, 'BsmtQual': TA    594
# Gd    592
# Ex    120
# Fa     32
# Name: BsmtQual, dtype: int64, 'BsmtCond': TA    1237
# Gd      62
# Fa      38
# After 1
# Name: BsmtCond, dtype: int64, 'BsmtExposure': No    887
# Of 213
# Gd    127
# Mn    111
# Name: BsmtExposure, dtype: int64, 'BsmtFinType1': GLQ    402
# Unf    392
# Alq 209
# Fir 141
# Rec    125
# LWQ 69
# Name: BsmtFinType1, dtype: int64, 'BsmtFinType2': Unf    1176
# Rec      53
# Lwq 46
# Fir 32
# Alq 19
# GLQ      12
# Name: BsmtFinType2, dtype: int64, 'Heating': GasA    1318
# Neat 16
# Grav       3
# OTH 1
# Name: Heating, dtype: int64, 'HeatingQC': Ex    704
# By 380
# Gd    217
# Fa     36
# After 1
# Name: HeatingQC, dtype: int64, 'CentralAir': Y    1277
# N      61
# Name: CentralAir, dtype: int64, 'Electrical': SBrkr    1242
# FOUNA 76
# FuseF      17
# FuseP       2
# Mix         1
# Name: Electrical, dtype: int64, 'KitchenQual': TA    650
# Gd    568
# Ex     97
# Fa     23
# Name: KitchenQual, dtype: int64, 'Functional': Typ     1254
# With us 30
# Min1 28
# Mod       11
# Maj 1 10
# Maj2 4
# Sev        1
# Name: Functional, dtype: int64, 'GarageType': Attchd     852
# Dectering 369
# BuiltIn     85
# Basment     19
# CarPort      7
# 2Types       6
# Name: GarageType, dtype: int64, 'GarageFinish': Unf    580
# West Germany 413
# Fin    345
# Name: GarageFinish, dtype: int64, 'GarageQual': TA    1270
# Fa      48
# Gd      14
# After 3
# Ex       3
# Name: GarageQual, dtype: int64, 'GarageCond': TA    1287
# Fa      33
# Gd       9
# After 7
# Ex       2
# Name: GarageCond, dtype: int64, 'PavedDrive': Y    1257
# N      54
# P      27
# Name: PavedDrive, dtype: int64, 'SaleType': WD       1158
# New       117
# COD        42
# ConLD       6
# Conlw 4
# Congi 4
# CWD         4
# Con         2
# Oth         1
# Name: SaleType, dtype: int64, 'SaleCondition': Normal     1104
# Partial     120
# Abnorml      86
# Family       20
# Alloca 7
# Adjland 1
# Name: SaleCondition, dtype: int64}
# ```

# %% [markdown]
# ### Step 3
#
# You are given the ```dirty_str_house_prices.csv``` data. Your goal is to clean it using methods provided by ```pandas``` such as ```DataFrame.apply()```, ```DataFrame.str.lower()```, etc. Any non-alphanumeric characters can be considered noise.
#
# **Please be careful when exploring the data.**

# %%
#Начало вашего кода
dirty_data=pd.read_csv("dirty_str_house_prices.csv")
dirty_data.set_index("Id",inplace=True)
del dirty_data["Unnamed: 0"]
#Конец вашего кода
print(dirty_data)
# Out:
#      MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope  \
# Id
# 1         rl:   PAVE.     ;REg       \tlvl   AllPub.     InsidE:      gtl
# 2       ...RL   <PAVE    reg\t        Lvl;  AllPUb\t        FR2       Gtl<
# 3        ;Rl    Pave      ir1?        LVL!   Allpub!    ?inside     ...Gtl
# 4          rl   pave.     ;IR1        .Lvl  ;ALLPUB;     >Corner      ;GTL
# 5       .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub        ?fr2   .GTL...
# ...       ...     ...      ...         ...       ...         ...       ...
# 1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;
# 1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.
# 1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl
# 1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl
# 1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1        COLLGCR<      norm;      NORM.  ...     SBRKr         gd\t
# 2       veenker\t    ?FEedr.      ;norm  ...    \tSBRKR         ta?
# 3        ?COLLGCR      !Norm     .norm>  ...     sbrkr<         .Gd
# 4        .CRAWFOR       NORm      NORM:  ...    \tSbrkr         Gd<
# 5       ?NoRIdge>   ...NORM<      Norm;  ...    \tSbrkr         GD;
# ...           ...        ...        ...  ...        ...         ...
# 1456   \tGilbert:      Norm?       NORM  ...     >sbrkr         .ta
# 1457    ...NWAMEs    NORM...     \tnorm  ...      SBRKR         TA!
# 1458    >CRAWfoR<       Norm    Norm...  ...     Sbrkr;         !Gd
# 1459        names       norm    \tnorm.  ...   \tFUseA:         Gd!
# 1460    \tEdwards    !NORM\t      norm?  ...    ;SBRKR?        ;ta:
#
#      Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1           TYP    AttChd<         .RFn       TA\t      \tTA<         y?
# 2          ;TYP    Attchd>        RFn\t       \tTa      >TA\t        ;Y!
# 3        TyP...    Attchd;         ;RFN    \tTA...        TA           Y
# 4          !TYP  DETCHD...         UNF?      \tTa;        ;Ta         .Y
# 5         <Typ>   Attchd\t        !rfn>       TA\t         Ta       \tY>
# ...         ...        ...          ...        ...        ...        ...
# 1456       !TYP    ;Attchd         :RFn        TA<        :Ta         Y;
# 1457      MIn1?    ATTCHD<         :unf       >Ta>        ?TA       >Y\t
# 1458       :TyP    AttChD<         ?Rfn        >TA       :TA:         .Y
# 1459        TYP    attchd.          Unf       :Ta;       \tTA       ...Y
# 1460       typ:    .ATTCHD          FIn       >ta?      \tta<      >y...
#
#      SaleType SaleCondition
# Id
# 1         wd      \tNormal?
# 2         Wd        Normal.
# 3         WD;        NORMAL
# 4         wd.     ABNORML\t
# 5        ?WD!       NoRmAl>
# ...       ...           ...
# 1456      Wd?     normal...
# 1457      Wd;     \tNormal;
# 1458     >wd!      :NORMAL;
# 1459     <WD!       :normal
# 1460      Wd;       ;NORMAL
#
# [1338 rows x 38 columns]

# %% [markdown]
# ###  Expected results:
#
# ```
# MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope  \
# Id
# 1         rl:   PAVE.     ;REg       \tlvl   AllPub.     InsidE:      gtl
# 2       ...RL   <PAVE    reg\t        Lvl;  AllPUb\t        FR2       Gtl<
# 3        ;Rl    Pave      ir1?        LVL!   Allpub!    ?inside     ...Gtl
# 4          rl   pave.     ;IR1        .Lvl  ;ALLPUB;     >Corner      ;GTL
# 5       .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub        ?fr2   .GTL...
# ...       ...     ...      ...         ...       ...         ...       ...
# 1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;
# 1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.
# 1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl
# 1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl
# 1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...
#
# Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1        COLLGCR<      norm;      NORM.  ...     SBRKr         gd\t
# 2 Veenker \ T? Feedr.      ; norm ... \ tsbrk to?
# 3        ?COLLGCR      !Norm     .norm>  ...     sbrkr<         .Gd
# 4        .CRAWFOR       NORm      NORM:  ...    \tSbrkr         Gd<
# 5       ?NoRIdge>   ...NORM<      Norm;  ...    \tSbrkr         GD;
# ...           ...        ...        ...  ...        ...         ...
# 1456 \ Tgilbert: Norm?       NORM ...> SBRKR .TA
# 1457 ... NWAMES NORM ... \ TNORM ... SBRKR TA!
# 1458    >CRAWfoR<       Norm    Norm...  ...     Sbrkr;         !Gd
# 1459        names       norm    \tnorm.  ...   \tFUseA:         Gd!
# 1460    \tEdwards    !NORM\t      norm?  ...    ;SBRKR?        ;ta:
#
# Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1 TYP attent, \ttTA)
# 2 ;TYP Attchdd> RF\t >TE >TAt ;
# 3 typs ... Event;         ; Rfn \ tta ... Ta y
# 4 !TY DETCHD… UNF?      \tLate        ; Yes
# <Typ\t\t <Typd\t <Typd\t There is a glory
# ...         ...        ...          ...        ...        ...        ...
# 1456 !TY PRAIT< :RFs HATil.
# 1457 MI1?    ATTCHD< :unf ?TA>
# 1458 :TyP.Rfn >Rfn >TA: .Ye
# 1459 TYP TYP.          Unf :Yes;       \tTA ...These
# 1460 typ: .ATTCHD FIn > is?      \tta< >...
#
# Saletype salecondition
# Id
# 1         wd      \tNormal?
# 2         Wd        Normal.
# 3         WD;        NORMAL
# 4         wd.     ABNORML\t
# 5        ?WD!       NoRmAl>
# ...       ...           ...
# 1456      Wd?     normal...
# 1457      Wd;     \tNormal;
# 1458     >wd!      :NORMAL;
# 1459     <WD!       :normal
# 1460      Wd;       ;NORMAL
#
# [1338 rows x 38 columns]
# ```

# %%
pd_dirty_data=dirty_data.copy()

# %%
st1 = '..ST'
st2 = '.KZ'

# %%
from os import replace
from django.urls import include


def dirty_data1(data):

    if "Id" in data.columns:
        data = data.set_index("Id")

    col = data.select_dtypes(include="object").columns 
    data[col] = (
        data[col] 
        .apply(lambda s: (
            s.astype(str) 
                .str.replace(r"[^A-Za-z0-9]", " ", regex=True) 
                .str.replace(r"\s+", " ", regex=True) 
                .str.strip() 
                .str.upper() 
    ))
    )
    
    return data
    
pd_dirty_data=dirty_data1(pd_dirty_data)

print(pd_dirty_data.head())
# Out:
#    MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 2        RL   PAVE      REG         LVL    ALLPUB       FR2       GTL
# 3        RL   PAVE      IR1         LVL    ALLPUB    INSIDE       GTL
# 4        RL   PAVE      IR1         LVL    ALLPUB    CORNER       GTL
# 5        RL   PAVE      IR1         LVL    ALLPUB       FR2       GTL
#
#    Neighborhood Condition1 Condition2  ... Electrical KitchenQual Functional  \
# Id                                     ...
# 1       COLLGCR       NORM       NORM  ...      SBRKR          GD        TYP
# 2       VEENKER      FEEDR       NORM  ...      SBRKR          TA        TYP
# 3       COLLGCR       NORM       NORM  ...      SBRKR          GD        TYP
# 4       CRAWFOR       NORM       NORM  ...      SBRKR          GD        TYP
# 5       NORIDGE       NORM       NORM  ...      SBRKR          GD        TYP
#
#    GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# Id
# 1      ATTCHD          RFN         TA         TA          Y       WD
# 2      ATTCHD          RFN         TA         TA          Y       WD
# 3      ATTCHD          RFN         TA         TA          Y       WD
# 4      DETCHD          UNF         TA         TA          Y       WD
# 5      ATTCHD          RFN         TA         TA          Y       WD
#
#    SaleCondition
# Id
# 1         NORMAL
# 2         NORMAL
# 3         NORMAL
# 4        ABNORML
# 5         NORMAL
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Expected results:
#
# ```
# MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 2          RL   PAVE      REG         LVL    ALLPUB       FR2       GTL
# 3          RL   PAVE      IR1         LVL    ALLPUB    INSIDE       GTL
# 4          RL   PAVE      IR1         LVL    ALLPUB    CORNER       GTL
# 5          RL   PAVE      IR1         LVL    ALLPUB       FR2       GTL
# ...       ...    ...      ...         ...       ...       ...       ...
# 1456       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1457       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1458       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1459       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1460       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
#
# Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 2 Veenker Feed Spring ... Sbrk TA
# 3         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 4         CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 5         NORIDGE       NORM       NORM  ...      SBRKR          GD
# ...           ...        ...        ...  ...        ...         ...
# 1456      GILBERT       NORM       NORM  ...      SBRKR          TA
# 1457 NWAMES NORM NORM ... SBRKR TA
# 1458      CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 1459        NAMES       NORM       NORM  ...      FUSEA          GD
# 1460 Edwards Norm Norm ... Patience Ta
#
# Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1 TYP ATCHD ATCHD ATCHD AND
# 2 ATTCHD RFN ATCHD ATCHD AND
# 3 TYP ATCHD ATCHD ATCHD AND
# 4 TYP DETCHD UNF THE ONF THE
# 5 TYP ATCHD ATCHD ATCHD AND
# ...         ...        ...          ...        ...        ...        ...
# 1456 TYP ATCHD RFN ATCHD AT
# 1457 min1 Attchd UNF TA Y Y
# 1458 TYP ATCHD RFN ATCHD AT
# 1459 TYP ATCHD ATCHD THE AND
# 1460 TYP ATCHD FING THE
#
# Saletype salecondition
# Id
# 1          WD        NORMAL
# 2          WD        NORMAL
# 3          WD        NORMAL
# 4          WD       ABNORML
# 5          WD        NORMAL
# ...       ...           ...
# 1456       WD        NORMAL
# 1457       WD        NORMAL
# 1458       WD        NORMAL
# 1459       WD        NORMAL
# 1460       WD        NORMAL
#
# [1338 rows x 38 columns]
# ```

# %% [markdown]
# ### Step 4
#
# After cleaning ```pd_dirty_data```, compare it with ```pd_data```. Do we need to make some changes to ```pd_data``` or/and ```pd_dirty_data``` to make a fair comparison? Implement ```compare_dataframes(pd_data, pd_dirty_data)``` function that will compare input ```DataFrames```.

# %%
#Начало вашего кода

def ensure_index_id(data: pd.DataFrame) -> pd.DataFrame: 
    d = data.copy() 
    if "Id" in d.columns: 
        d = d.set_index("Id") 
    return d 

def normalise(s: pd.Series) -> pd.Series: 
    return (s.astype(str)
            .str.replace(r"\s+", " ", regex=True)
            .str.strip() 
            .str.upper()) 

def compare_dataframes(pd_data: pd.DataFrame, pd_dirty_data: pd.DataFrame) -> pd.Series:
    #both index id 
    A = ensure_index_id(pd_data).reset_index(drop=True)
    B = ensure_index_id(pd_dirty_data).reset_index(drop=True)

    # only compare the cols in dirty data set 
    cols_dirt = B.select_dtypes(include="object").columns 
    common_cols = cols_dirt.intersection(A.columns) 

    #align rows 
    A = A[common_cols]
    B = B[common_cols]

    #normalise and percentage match 
    sims = {} 
    for col in common_cols: 
        a = normalise(A[col]) 
        b = normalise(B[col]) 
        total = len(a) 
        sims[col] = (a == b).sum() / total * 100 if total else float("nan")

    #return series sort by name 
    data_need = pd.Series(sims) 
    data_need.name = "(%) same"

    return data_need
#Конец вашего кода
print(compare_dataframes(pd_data, pd_dirty_data))
# Out:
# MSZoning          99.402093
# Street            99.925262
# LotShape          99.925262
# LandContour       99.925262
# Utilities         99.925262
# LotConfig         99.925262
# LandSlope         99.925262
# Neighborhood      99.925262
# Condition1       100.000000
# Condition2        99.925262
# BldgType          99.925262
# HouseStyle        87.892377
# RoofStyle         99.925262
# RoofMatl          99.252616
# Exterior1st       99.925262
# Exterior2nd       99.925262
# MasVnrType        44.245142
# ExterQual        100.000000
# ExterCond         99.925262
# Foundation        99.925262
# BsmtQual          99.925262
# BsmtCond          99.925262
# BsmtExposure      99.925262
# BsmtFinType1      99.925262
# BsmtFinType2      99.925262
# Heating           99.925262
# HeatingQC         99.925262
# CentralAir        99.925262
# Electrical        99.925262
# KitchenQual       99.925262
# Functional        99.925262
# GarageType        99.925262
# GarageFinish      99.925262
# GarageQual        99.925262
# GarageCond        99.925262
# PavedDrive        99.925262
# SaleType          99.925262
# SaleCondition     99.925262
# Name: (%) same, dtype: float64

# %% [markdown]
# ### Expected results:
#
# ```
# (%) same
# Mszoning 100,000000
# Street         100.000000
# Lotshepage 100.000000
# LandContour    100.000000
# Utilities      100.000000
# LotConfig      100.000000
# LandSlope      100.000000
# Neighborhood   100.000000
# Condition1 100.000000
# Condition2     100.000000
# BldgType       100.000000
# HouseStyle      87.967115
# ROOF STYLE 100.000000
# RoofMatl       100.000000
# Exterior1st    100.000000
# Exterior2nd    100.000000
# MasVnrType     100.000000
# ExterQual      100.000000
# ExterCond      100.000000
# Foundation     100.000000
# BsmtQual       100.000000
# BsmtCond       100.000000
# BsmtExposure   100.000000
# BsmtFinType1   100.000000
# BsmtFinType2   100.000000
# Heating        100.000000
# HeatingQC      100.000000
# CentralAir     100.000000
# Electrical     100.000000
# KitchenQual    100.000000
# Functional     100.000000
# Garage type 100.000000
# GarageFinish   100.000000
# GarageQual     100.000000
# GarageCond     100.000000
# PavedDrive     100.000000
# SaleType       100.000000
# Salecondition 100.000000
# ```

# %% [markdown]
# # Good Job!
